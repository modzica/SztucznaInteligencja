# %% [markdown]
# 1.Funkcja risk_score oblicza uproszczony wskaznik ryzyka na podstawie 3 parametrow:
# -sprawdza czy dane wejsciowe sa poprawne
# -liczy risk score zgodnie ze wzorem
# -zaokragla wynik do 2 miejsc po przecinku.
# Wiekszy wynik -> wieksze ryzyko
# Mniejszy wynik -> mniejsze ryzyko

# %% [markdown]
# 2.AI zmienilo swoje testy (plik test_risk_score_EDITBYAI.py
